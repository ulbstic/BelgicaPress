# %%
from belgicapress import *
import time

#pd.set_option('display.max_rows', None) #pour visualiser toutes les lignes des dataframes, pas si gros dans ce cas-ci

# %%
annot = pd.read_csv(r'06_QueriesByVisit_towork2.csv', encoding="utf-8", engine="c", index_col="unique_id")

annot = annot.drop("query_tokens", axis=1)
annot = annot.rename(columns={'query_normalised': 'queries'})
annot.head()
# Out:
#            visitID  Column                             queries
# unique_id
# 0-649635    649635       0                      london diamond
# 1-649635    649635       1              london diamond-workers
# 2-649635    649635       2  london diamond-workers trade union
# 3-649756    649756       3                            bioscope
# 4-649756    649756       4                              cinéma

# %%
prenoms = pd.read_csv(r"C:\Users\Boulot\Desktop\BelgicaPress\prenoms.tsv", encoding="utf8")
prenoms = set([str(name).strip().lower() for name in prenoms.prenoms])

# %%
noms_famille = pd.read_csv(r"C:\Users\Boulot\Desktop\BelgicaPress\patronymes_fusionnes.csv", encoding="utf8")
noms_famille = set([name.strip().lower() for name in noms_famille.Nom])

# %%
communes_complet = pd.read_csv(r"C:\Users\Boulot\Desktop\BelgicaPress\communes_et_sections.csv", encoding="utf8")

# %%
liste_mots = pd.read_csv(r"C:\Users\Boulot\Desktop\BelgicaPress\liste_mots.tsv", encoding="utf8")
liste_mots = set([name.strip().lower() for name in liste_mots.mots])

# %%
geo = pd.read_csv(r"C:\Users\Boulot\Desktop\BelgicaPress\communes_et_sections_noms_unifies.csv", encoding="utf8")
geo = geo.drop_duplicates(['noms_unifie'])
geo['lower'] = geo['noms_unifie'].str.lower()
lieux_be = set([str(name).strip() for name in geo.lower])

# %%
annot["extract_lieux_be"] = annot['queries'].apply(lambda x: get_lieux_clean(x, lieux_be, prenoms))
annot.head()
# Out:
#            visitID  Column                             queries  \
# unique_id
# 0-649635    649635       0                      london diamond
# 1-649635    649635       1              london diamond-workers
# 2-649635    649635       2  london diamond-workers trade union
# 3-649756    649756       3                            bioscope
# 4-649756    649756       4                              cinéma
#
#           extract_lieux_be
# unique_id
# 0-649635
# 1-649635
# 2-649635
# 3-649756
# 4-649756

# %%
annot = tidy_split(annot, 'extract_lieux_be', sep='||')
annot

# %% [markdown]
# extract_geonames = pd.DataFrame(annot['extract_lieux_be'].dropna().unique(), columns = ["name"])
#
# geonames = extract_geonames.merge(geo, left_on='name', right_on='lower', how='left')

# %%
annot_geo = pd.merge(annot, geo, left_on="extract_lieux_be", right_on="lower", how="left")
annot_geo

# %%
#PROBLEME !
#df_merged = pd.merge(annot_geo, communes_complet.drop_duplicates(['noms_unifie']), left_on="nom_original", right_on="nom_original", how="left")
#df_merged

# %%
patronymes_locaux = []
annot['extract_persons'] = annot['queries'].apply(lambda x: get_personnes_patronymes(x, prenoms, lieux_be, liste_mots, noms_famille, patronymes_locaux))
seen = set()
seen_add = seen.add
patronymes_locaux = [x.lower() for x in patronymes_locaux if not (x in seen or seen_add(x)) and x is not '']

# %%
patronymes_locaux.sort()
patronymes_locaux
# Out:
# ['aalto',
#  'abas',
#  'abbeelan',
#  'abeele',
#  'abha',
#  'abinet',
#  'ablay',
#  'abraham',
#  'abras',
#  'abrassart',
#  'academie',
#  'acatene',
#  'accordeons',
#  'achten',
#  'aciana',
#  'acke',
#  'acker',
#  'acton',
#  'adam',
#  'adant',
#  'adegem',
#  'adele',
#  'adelot',
#  'ader',
#  'adler',
#  'adolphe',
#  'adolphine',
#  'adriaensen',
#  'adriani',
#  'adrien',
#  'adrienne',
#  'aeronaute',
#  'aeroplanes',
#  'aerostier',
#  'aerts',
#  'affaire',
#  'afgrond',
#  'afrique',
#  'agent',
#  'agneessens',
#  'agnesi',
#  'agnete',
#  'agniez',
#  'ahin',
#  'ahmed',
#  'ahn',
#  'aime',
#  'aisnes',
#  'ait',
#  'ajax',
#  'akkerman',
#  'alban',
#  'albert',
#  'albertine',
#  'albertini',
#  'albrecht',
#  'aldenhoven',
#  'alder',
#  'alderson',
#  'alebric',
#  'aleida',
#  'alex',
#  'alexandre',
#  'alfen',
#  'algerie',
#  'ali',
#  'alida',
#  'alimani',
#  'alken',
#  'alker',
#  'allaer',
#  'allaert',
#  'allais',
#  'allard',
#  'allary',
#  'allemand',
#  'alleyne',
#  'allgemagne',
#  'alma',
#  'alois',
#  'alos',
#  'alost',
#  'alouett',
#  'alpers',
#  'alphen',
#  'alphonse',
#  'altena',
#  'altmann',
#  'altmeyer',
#  'amand',
#  'amanda',
#  'ambreville',
#  'amed',
#  'amedee',
#  'amedeo',
#  'amelda',
#  'americo',
#  'amitie',
#  'amleto',
#  'amour',
#  'amundsen',
#  'anciau',
#  'ancien',
#  'and',
#  'andaluzia',
#  'anden',
#  'anderlecht',
#  'andersson',
#  'andre',
#  'andreas',
#  'andres',
#  'andrews',
#  'andriessen',
#  'anestehsist',
#  'angelle',
#  'angers',
#  'anglo',
#  'ann',
#  'anna',
#  'anonyme',
#  'ans',
#  'ansiaux',
#  'anspach',
#  'ansvers',
#  'anthoine',
#  'anthony',
#  'anticlericale',
#  'anticlericaux',
#  'antoine',
#  'antoing',
#  'antwerpen',
#  'anvers',
#  'apel',
#  'apers',
#  'appel',
#  'appelterre',
#  'aragon',
#  'arbaletriers',
#  'arbre',
#  'archangel',
#  'arctowsky',
#  'ardoise',
#  'arenberg',
#  'argenteuil',
#  'argentueil',
#  'arhur',
#  'arijs',
#  'arlon',
#  'armand',
#  'arme',
#  'armee',
#  'armelda',
#  'armer',
#  'armes',
#  'armstrong',
#  'arno',
#  'arnould',
#  'aron',
#  'arral',
#  'arseele',
#  'art',
#  'arthur',
#  'artistic',
#  'artois',
#  'ason',
#  'assaier',
#  'assaut',
#  'asselberghs',
#  'asselbergs',
#  'astley',
#  'asturies',
#  'auberge',
#  'aubly',
#  'aubry',
#  'audenhove',
#  'audent',
#  'august',
#  'auguste',
#  'augustin',
#  'aumonier',
#  'autekie',
#  'auteuil',
#  'autome',
#  'autrique',
#  'auwera',
#  'avenir',
#  'averino',
#  'avn',
#  'avoort',
#  'azijn',
#  'baankampioenschap',
#  'baarle',
#  'babel',
#  'babeno',
#  'babenos',
#  'babou',
#  'babusiaux',
#  'bacall',
#  'bach',
#  'back',
#  'backer',
#  'backx',
#  'bacot',
#  'bacq',
#  'bady',
#  'baedeckers',
#  'baelde',
#  'baele',
#  'baels',
#  'baert',
#  'baesens',
#  'baeten',
#  'baetes',
#  'baets',
#  'baha',
#  'bail',
#  'bailleux',
#  'bailly',
#  'baisir',
#  'baisse',
#  'baiwir',
#  'baker',
#  'baladeuseateliers',
#  'balasse',
#  'balcaen',
#  'balens',
#  'ballester',
#  'ballet',
#  'balletten',
#  'ballon',
#  'ballot',
#  'bals',
#  'balthazar',
#  'bandagist',
#  'bangels',
#  'bank',
#  'banker',
#  'banning',
#  'bapteme',
#  'baptist',
#  'baptiste',
#  'bar',
#  'baraque',
#  'barbe',
#  'barbier',
#  'barbieux',
#  'barbuse',
#  'bardou',
#  'bare',
#  'barette',
#  'bark',
#  'barlach',
#  'barmat',
#  'baron',
#  'baronne',
#  'barragan',
#  'barres',
#  'bartels',
#  'bartiaux',
#  'baruch',
#  'bas',
#  'bascourt',
#  'basile',
#  'basse',
#  'bassompierre',
#  'bastin',
#  'bastyns',
#  'bataille',
#  'bateur',
#  'batteur',
#  'bauchau',
#  'baudin',
#  'baudot',
#  'baudour',
#  'baudoux',
#  'baudry',
#  'bauer',
#  'baugniers',
#  'baugnies',
#  'baugniet',
#  'baumgart',
#  'bauthier',
#  'bautier',
#  'bautil',
#  'bauw',
#  'bauwel',
#  'bauwens',
#  'bavery',
#  'baviere',
#  'bax',
#  'bayet',
#  'bayton',
#  'beard',
#  'beauck',
#  'beaudoin',
#  'beauffort',
#  'beaujean',
#  'beaulieu',
#  'bebaets',
#  'becaud',
#  'becker',
#  'beckers',
#  'beckman',
#  'beckwith',
#  'beco',
#  'beeckman',
#  'beeld',
#  'begrafenis',
#  'begrafenissen',
#  'beha',
#  'beheyt',
#  'bej',
#  'bekaert',
#  'belge',
#  'belgica',
#  'belgie',
#  'beliard',
#  'bell',
#  'bellefroid',
#  'belliardstraat',
#  'belliere',
#  'bellis',
#  'bellune',
#  'belot',
#  'belouet',
#  'belvaux',
#  'bemden',
#  'benard',
#  'benario',
#  'bende',
#  'benedictin',
#  'beng',
#  'benoit',
#  'benoni',
#  'benoot',
#  'benot',
#  'benson',
#  'bequet',
#  'berael',
#  'beranger',
#  'berchem',
#  'berchmans',
#  'berckmans',
#  'berden',
#  'berens',
#  'berger',
#  'bergh',
#  'berghe',
#  'berghman',
#  'beric',
#  'bernard',
#  'bernays',
#  'bernhardt',
#  'bernheim',
#  'bernstein',
#  'berquin',
#  'berr',
#  'berrick',
#  'berryer',
#  'berryerfernand',
#  'bert',
#  'bertall',
#  'berth',
#  'berthel',
#  'bertheroy',
#  'bertrand',
#  'bertrandadolphe',
#  'bertrandjacques',
#  'besancon',
#  'besme',
#  'bestiaux',
#  'bestolen',
#  'betoging',
#  'beton',
#  'bettens',
#  'bettonville',
#  'beumer',
#  'beumier',
#  'beurden',
#  'beurre',
#  'beurs',
#  'bey',
#  'beyaert',
#  'bgvan',
#  'bhme',
#  'bianchi',
#  'bianco',
#  'biarent',
#  'biava',
#  'bibliotheque',
#  'biddaer',
#  'bie',
#  'biebuyck',
#  'biere',
#  'bieren',
#  'bieres',
#  'bierset',
#  'biesbroeck',
#  'biesemans',
#  'bija',
#  'bilbao',
#  'bilcke',
#  'billebeeck',
#  'biloque',
#  'binard',
#  'bing',
#  'binon',
#  'bioscoop',
#  'birguer',
#  'bischop',
#  'bisschops',
#  'bivort',
#  'bixschote',
#  'black',
#  'blairon',
#  'blaise',
#  'blanc',
#  'blanchan',
#  'blanche',
#  'blanquart',
#  'blaton',
#  'blesses',
#  'blickx',
#  'blieck',
#  'bligh',
#  'block',
#  'blockhuys',
#  'bloemen',
#  'bloemgarden',
#  'bloemgarten',
#  'blomme',
#  'blondeel',
#  'blume',
#  'blumel',
#  'blunck',
#  'blyckaerts',
#  'bni',
#  'bob',
#  'boch',
#  'bock',
#  'bocken',
#  'bockstael',
#  'bodson',
#  'boe',
#  'boeck',
#  'boeckel',
#  'boehme',
#  'boekhouder',
#  'boekhouding',
#  'boel',
#  'boelen',
#  'boen',
#  'boens',
#  'boeren',
#  'boergeneraal',
#  'boetvaardige',
#  'boeyen',
#  'boeynaems',
#  'bogaert',
#  'bogaerts',
#  'bohie',
#  'bohlen',
#  'bohme',
#  'boin',
#  'boinem',
#  'boiron',
#  'bois',
#  'boisde',
#  'boitt',
#  'boitte',
#  'boland',
#  'bolle',
#  'bollen',
#  'bolly',
#  'bols',
#  'boma',
#  'bomart',
#  'bon',
#  'bonaert',
#  'bonaparte',
#  'bonaugure',
#  'bond',
#  'bondt',
#  'bonduelle',
#  'bone',
#  'bonet',
#  'bonheur',
#  'boni',
#  'boniver',
#  'bonjean',
#  'bonnerue',
#  'bonnet',
#  'bonte',
#  'boogaert',
#  'boogschieten',
#  'booker',
#  'boomvan',
#  'boon',
#  'boonaert',
#  'boone',
#  'boos',
#  'bor',
#  'bordet',
#  'borel',
#  'bores',
#  'borges',
#  'borghs',
#  'borgnet',
#  'borms',
#  'borremans',
#  'borsu',
#  'bos',
#  'bosch',
#  'bosco',
#  'bosman',
#  'bosquet',
#  'bossche',
#  'bosschere',
#  'bosschvoorde',
#  'bossu',
#  'bossut',
#  'botelberge',
#  'botte',
#  'boucart',
#  'bouche',
#  'boucher',
#  'boucherie',
#  'bouchery',
#  'bouckaert',
#  'bouge',
#  'bougmestre',
#  'bougnon',
#  'bouhaye',
#  'bouillon',
#  'boulanger',
#  'boulenger',
#  'boulger',
#  'boulvin',
#  'bouly',
#  'bouman',
#  'bourdeau',
#  'bourdon',
#  'boure',
#  'bourgeois',
#  'bourgogne',
#  'bourguignon',
#  'bourquin',
#  'bourse',
#  'boursier',
#  'boute',
#  'boutry',
#  'bouvet',
#  'bouvier',
#  'bouvrie',
#  'bovie',
#  'bovy',
#  'box',
#  'boxe',
#  'boxtael',
#  'boyaert',
#  'boyen',
#  'boys',
#  'brabant',
#  'brabantgeen',
#  'brabantlouis',
#  'brabantward',
#  'brachet',
#  'bracquegnies',
#  'bradbury',
#  'braeckelaere',
#  'braeckman',
#  'braekman',
#  'braet',
#  'brahm',
#  'braine',
#  'brainet',
#  'braive',
#  'brancart',
#  'branch',
#  'brand',
#  'brandeis',
#  'brandels',
#  'brandes',
#  'brans',
#  'brasseur',
#  'brauer',
#  'braun',
#  'brauns',
#  'breart',
#  'brebart',
#  'brefaut',
#  'bremer',
#  'brener',
#  'brenez',
#  'brenon',
#  'bresil',
#  'breuer',
#  'breugelmans',
#  'brewer',
#  'breynaert',
#  'briand',
#  'brias',
#  'brieart',
#  'brion',
#  'briquet',
#  'brockmans',
#  'brodie',
#  'broeckaert',
#  'broeder',
#  'broeders',
#  'broerman',
#  'broka',
#  'bron',
#  'bronchain',
#  'bronte',
#  'bronti',
#  'broqueville',
#  'broughton',
#  'brouns',
#  'broustin',
#  'brouwer',
#  'brouwerij',
#  'broymans',
#  'bruce',
#  'bruck',
#  'bruegel',
#  'bruelle',
#  'bruggeman',
#  'bruijninckx',
#  'brun',
#  'brunain',
#  'brunfaut',
#  'bruni',
#  'brunin',
#  'brunner',
#  'brunot',
#  'bruns',
#  'brusselmans',
#  'brusselsmans',
#  'bruxelles',
#  'bruyere',
#  'bruylants',
#  'bruyn',
#  'bruyninckx',
#  'bruyr',
#  'buchet',
#  'buckincx',
#  'budo',
#  'buelens',
#  'buffa',
#  'buffalo',
#  'buffet',
#  'bufquin',
#  'bugny',
#  'buisseret',
#  'buisset',
#  'buissiere',
#  'bulard',
#  'bulcke',
#  'bull',
#  'buls',
#  'bult',
#  'bultinck',
#  'bunner',
#  'buns',
#  'buntincx',
#  'buntinx',
#  'bunyan',
#  'buonarroti',
#  'bureau',
#  'buret',
#  'burgemeester',
#  'burgeon',
#  'burie',
#  'burne',
#  'burton',
#  'busine',
#  'busschots',
#  'busson',
#  'butler',
#  'buurmans',
#  'buyck',
#  'buyl',
#  'buyle',
#  'buys',
#  'buyse',
#  'buysse',
#  'cabanier',
#  'cabaret',
#  'cabuil',
#  'cadavre',
#  'cador',
#  'cafe',
#  'caffi',
#  'cahen',
#  'caillet',
#  'cailli',
#  'cajot',
#  'calavar',
#  'calende',
#  'callebert',
#  'callens',
#  'callewaert',
#  'callier',
#  'calmeyn',
#  'calus',
#  'calvaire',
#  'calvert',
#  'calvino',
#  'camara',
#  'cambier',
#  'cambresier',
#  'camiel',
#  'camille',
#  'cammaert',
#  'camp',
#  'campenhout',
#  'canadia',
#  'canadian',
#  'canal',
#  'canari',
#  'candaele',
#  'canhter',
#  'canivez',
#  'cannaers',
#  'cannes',
#  'canon',
#  'canonniere',
#  'canter',
#  'canther',
#  'cantine',
#  'cantor',
#  'capart',
#  'capelle',
#  'capellle',
#  'capiau',
#  'capiaux',
#  'capitain',
#  'capitaine',
#  'cara',
#  'carabiner',
#  'carcan',
#  'carlier',
#  'carmen',
#  'carnera',
#  'carnieres',
#  'carnotstraat',
#  'caro',
#  'caroline',
#  'carolus',
#  'caroly',
#  'caron',
#  'carpay',
#  'carpels',
#  'carpentier',
#  'carriers',
#  'carriersguillaume',
#  'carroen',
#  'carte',
#  'carton',
#  'casa',
#  'casablanca',
#  'casement',
#  'casernemarie',
#  'casino',
#  'casman',
#  'cassel',
#  'cassimon',
#  'castau',
#  'castelain',
#  'castelein',
#  'castelot',
#  'casterman',
#  'castiau',
#  'castiaux',
#  'castiglione',
#  'cata',
#  'cataux',
#  'cateaux',
#  'catherine',
#  'catulle',
#  'cauberg',
#  'cauchie',
#  'caulier',
#  'celeste',
#  'celos',
#  'cense',
#  'censier',
#  'cercle',
#  'cerclevan',
#  'cerdan',
#  'cerf',
#  'cerviere',
#  'ceuleers',
#  'ceusters',
#  'ceysens',
#  'cezar',
#  'chabas',
#  'chabau',
#  'chabeau',
#  'chabry',
#  'chalon',
#  'chamberlain',
#  'chambige',
#  'chambon',
#  'chambord',
#  'champtre',
#  'chandler',
#  'change',
#  'changescharles',
#  'chanoine',
#  'chanson',
#  'chansonnettenvan',
#  'chansonnettevan',
#  'chanteur',
#  'chantier',
#  'chapelier',
#  'chapelle',
#  'chaplin',
#  'chappe',
#  'charbon',
#  'charleroicoucke',
#  'charleroifin',
#  'charleroijacques',
#  'charleroiles',
#  'charleroimaison',
#  'charleroimartyrs',
#  'charles',
#  'charleston',
#  'charlier',
#  'charliers',
#  'charlotte',
#  'charron',
#  'chasse',
#  'chateau',
#  'chaudoir',
#  'chaudron',
#  'chaussee',
#  'chautard',
#  'chauviere',
#  'chauvin',
#  'chauvinleon',
#  'chavee',
#  'chef',
#  'chemin',
#  'chenal',
#  'chenois',
#  'cher',
#  'chermanne',
#  'chevalier',
#  'chevaux',
#  'chez',
#  'chi',
#  'chibert',
#  'chicoree',
#  'china',
#  'chinees',
#  'chineesch',
#  'chocolat',
#  'cholet',
#  'chome',
#  'choufernand',
#  'choulet',
#  'choux',
#  'chretien',
#  'christ',
#  'christens',
#  'christiaens',
#  'christine',
#  'christophe',
#  'christy',
#  'cimetiere',
#  'cincinatti',
#  'cincinnati',
#  'cine',
#  'cinema',
#  'cinematographe',
#  'circus',
#  'cirkus',
#  'ciselet',
#  'citroen',
#  'civile',
#  'civilesaint',
#  'claes',
#  'claeszen',
#  'claeys',
#  'claretie',
#  'clarot',
#  'clart',
#  'claude',
#  'claudy',
#  'claus',
#  'clausen',
#  'clauss',
#  'clemen',
#  'clemence',
#  'clement',
#  'clementine',
#  'clemer',
#  'clercq',
#  'clesse',
#  'clodomir',
#  'cloet',
#  'cloquet',
#  'closen',
#  'closiere',
#  'closon',
#  'closs',
#  'clossen',
#  'closset',
#  'closson',
#  'cloth',
#  'clown',
#  'cluck',
#  'cluysenaar',
#  'cluysenaer',
#  'cochaux',
#  'cock',
#  'cocquyt',
#  'cocymans',
#  'coecke',
#  'coedel',
#  'coelho',
#  'coenen',
#  'coeur',
#  'coeymans',
#  'cogen',
#  'cohen',
#  'colart',
#  'colbeau',
#  'colin',
#  'colinet',
#  'collart',
#  'colle',
#  'colleauc',
#  'colleaux',
#  'collecte',
#  'college',
#  'collette',
#  'colleye',
#  'collignon',
#  'collin',
#  'collinet',
#  'collins',
#  'collinszonder',
#  'collon',
#  'colmeyn',
#  'cologne',
#  'colomb',
#  'colpaert',
#  'combaz',
#  'commergo',
#  'commissaris',
#  'compagnie',
#  'companys',
#  'complementaire',
#  'compris',
#  'comte',
#  'comtesse',
#  'concert',
#  'conder',
#  'conference',
#  'conferentie',
#  'confo',
#  'congo',
#  'congoboone',
#  'congoverdrag',
#  'congres',
#  'conil',
#  'connelly',
#  'conover',
#  'conqute',
#  'conrad',
#  'conscience',
#  'conseiller',
#  'consitution',
#  'constant',
#  'constantinople',
#  'consul',
#  'conti',
#  'cook',
#  'cools',
#  'coolskamp',
#  'coomans',
#  'cooreman',
#  'cooremans',
#  'coosemans',
#  'coppee',
#  'coppel',
#  'coppens',
#  'coppin',
#  'corbisier',
#  'cordemans',
#  'cordier',
#  'corman',
#  'cornelis',
#  'cornelissen',
#  'corner',
#  'cornette',
#  'cornez',
#  ...]

# %%
annot['extract_family'] = annot['queries'].apply(lambda x: get_family_name(x, prenoms, noms_famille, patronymes_locaux, lieux_be))

# %%
extract_persons = pd.DataFrame(annot['extract_persons'].dropna().unique(), columns = ["persons_names"])
extract_persons
# Out:
#                         persons_names
# 0                      Diamond London
# 1                     Diamond Workers
# 2                      Rommel Charles
# 3                      Michel Pruvost
# 4                   Bernard Israelite
# 5                        Bridge Whist
# 6                     Daniel De Lange
# 7                   Wilhelmine Clauss
# 8                    Amalia Rodrigues
# 9                        Gillet Amour
# 10                   Gillet Lamouline
# 11                 Felix Van De Weghe
# 12                       Anna Nellens
# 13                      Marcel Dupuis
# 14                        Denis Saint
# 15                       Pierre Saint
# 16                   Victor Guillemin
# 17    Victor Guillemin Albert Gombert
# 18                  Beernaert Wilmart
# 19                     Pierre Willems
# 20                     Pieter Willems
# 21                    Denis Jacquemin
# 22                      Albert Panier
# 23                       Andre Boelen
# 24                       Gaston Block
# 25                     Mendes Catulle
# 26                      Vincent Lebbe
# 27                     Stevens Smeers
# 28                   Stevens Stacquet
# 29                    Leopold De Wael
# ...                               ...
# 8908                      Pierre Kryn
# 8909                      Jan Baptist
# 8910                    Bernard Meyer
# 8911                   Bernhard Meyer
# 8912                     Meyer Wahehe
# 8913                       Marc Sleen
# 8914                  Rodolphe Tppfer
# 8915                Willy Vandersteen
# 8916                   Frans Lenaerts
# 8917                   Charles Miller
# 8918                         Paul Bor
# 8919                      Paul Dangla
# 8920                   Denijs Balcaen
# 8921                Denijs Vandevenne
# 8922                       Ali Autome
# 8923                    Batiste Royal
# 8924                Batiste Bruxelles
# 8925                    Eugenio Bruni
# 8926                   Arnaud Dreyfus
# 8927                   Eleonore Gomez
# 8928                   Francois Gomez
# 8929                    Jacques Gomez
# 8930                 Leontine Lefevre
# 8931                   Marie Leclercq
# 8932          Marie Therese Desomberg
# 8933                     Henry Krauss
# 8934                    Martin Robyns
# 8935                  Charles Tuytens
# 8936                      Guy Stephan
# 8937                   Edouard Jacobs
#
# [8938 rows x 1 columns]

# %% [markdown]
# start_time = time.time()
# extract_persons['wikipedia_person'] = extract_persons['persons_names'].apply(lambda x: get_wikipedia(x) if len(x)> 1 else None)
# print("--- %s seconds ---" % (time.time() - start_time))

# %% [markdown]
# start_time = time.time()
# extract_persons['wikipedia_person'] = extract_persons['persons_names'].apply(lambda x: get_wikipedia(x) if len(x)> 1 else None)
# print("--- %s seconds ---" % (time.time() - start_time))

# %%
annot_geo

# %%
annot
# Out:
#                visitID  Column  \
# unique_id
# 0-649635        649635       0
# 1-649635        649635       1
# 2-649635        649635       2
# 3-649756        649756       3
# 4-649756        649756       4
# 5-649756        649756       5
# 6-649756        649756       6
# 7-649756        649756       7
# 8-649858        649858       8
# 9-649940        649940       9
# 10-649981       649981      10
# 11-649981       649981      11
# 12-649981       649981      12
# 13-649981       649981      13
# 14-650099       650099      14
# 15-650298       650298      15
# 16-650480       650480      16
# 17-650574       650574      17
# 18-650574       650574      18
# 19-650636       650636      19
# 20-650636       650636      20
# 21-650644       650644      21
# 22-650707       650707      22
# 23-650707       650707      23
# 25-651009       651009      25
# 24-651009       651009      24
# 26-651069       651069      26
# 27-651089       651089      27
# 28-651111       651111      28
# 29-651111       651111      29
# ...                ...     ...
# 83827-3248245  3248245   83827
# 83823-3248245  3248245   83823
# 83824-3248245  3248245   83824
# 83825-3248245  3248245   83825
# 83828-3248346  3248346   83828
# 83829-3248346  3248346   83829
# 83830-3248346  3248346   83830
# 83831-3248370  3248370   83831
# 83833-3248416  3248416   83833
# 83834-3248416  3248416   83834
# 83835-3248416  3248416   83835
# 83836-3248416  3248416   83836
# 83832-3248416  3248416   83832
# 83839-3248444  3248444   83839
# 83838-3248444  3248444   83838
# 83837-3248444  3248444   83837
# 83840-3248446  3248446   83840
# 83842-3248467  3248467   83842
# 83841-3248467  3248467   83841
# 83843-3248474  3248474   83843
# 83844-3248474  3248474   83844
# 83845-3248490  3248490   83845
# 83846-3248865  3248865   83846
# 83847-3248955  3248955   83847
# 83848-3248955  3248955   83848
# 83849-3248955  3248955   83849
# 83850-3248955  3248955   83850
# 83851-3248955  3248955   83851
# 83852-3248976  3248976   83852
# 83853-3248976  3248976   83853
#
#                                                          queries  \
# unique_id
# 0-649635                                          london diamond
# 1-649635                                  london diamond-workers
# 2-649635                      london diamond-workers trade union
# 3-649756                                                bioscope
# 4-649756                                                  cinéma
# 5-649756                                          cinématographe
# 6-649756                                         cinématographie
# 7-649756                                       cinématographique
# 8-649858                                      soucoupes volantes
# 9-649940                                        delbecq guignies
# 10-649981                                                cambron
# 11-649981                                                 coinne
# 12-649981                                                 coisne
# 13-649981                                                pruvost
# 14-650099                                            dendermonde
# 15-650298                                            dendermonde
# 16-650480                                           oud-strijder
# 17-650574      assenede bassevelde boekhoute bouchaute oost-e...
# 18-650574      assenede bassevelde bouchaute boekhoute oost-e...
# 19-650636                                                 bridge
# 20-650636                                                 britch
# 21-650644                                            dendermonde
# 22-650707                                                 rommel
# 23-650707                                         rommel charles
# 25-651009                                         pruvost michel
# 24-651009                                                pruvost
# 26-651069                                         parent-schaken
# 27-651089                                                  macan
# 28-651111                                brand carette moeskroen
# 29-651111                                  brand carette spinnen
# ...                                                          ...
# 83827-3248245                                            rabarot
# 83823-3248245                                    café restaurant
# 83824-3248245                                    café-restaurant
# 83825-3248245                                           henseval
# 83828-3248346                                drame de braconnage
# 83829-3248346                                     stroopersdrama
# 83830-3248346                                 wildstroopersdrama
# 83831-3248370                                           aernouts
# 83833-3248416                                    charles tuytens
# 83834-3248416                  comptoir commercial et industriel
# 83835-3248416                               thuysbaert-de ridder
# 83836-3248416                                            tuytens
# 83832-3248416                                     arnaud dreyfus
# 83839-3248444                                             h. col
# 83838-3248444                                    café-restaurant
# 83837-3248444                               6, rue de la station
# 83840-3248446                                        guy stephan
# 83842-3248467                 stade, louvain, louvaniste,leuven,
# 83841-3248467  stade, louvain, louvaniste, football, sports, ...
# 83843-3248474                                 rassenfosse-brouet
# 83844-3248474                                     serrurier-bovy
# 83845-3248490                                             horrue
# 83846-3248865                                 neder over hembeek
# 83847-3248955                                      arved poorten
# 83848-3248955                                      arwed poorten
# 83849-3248955                                     edouard jacobs
# 83850-3248955                      edouard jacobs violoncelliste
# 83851-3248955                             poorten violoncelliste
# 83852-3248976                                            de nave
# 83853-3248976                                            tuytens
#
#                                            extract_lieux_be  extract_persons  \
# unique_id
# 0-649635                                                      Diamond London
# 1-649635                                                     Diamond Workers
# 2-649635                                                     Diamond Workers
# 3-649756                                                                None
# 4-649756                                                                None
# 5-649756                                                                None
# 6-649756                                                                None
# 7-649756                                                                None
# 8-649858                                                                None
# 9-649940                                           guignies             None
# 10-649981                                                               None
# 11-649981                                                               None
# 12-649981                                                               None
# 13-649981                                                               None
# 14-650099                                       dendermonde             None
# 15-650298                                       dendermonde             None
# 16-650480                                                               None
# 17-650574      boekhoute||assenede||bassevelde||oost-eecloo             None
# 18-650574      boekhoute||assenede||bassevelde||oost-eecloo             None
# 19-650636                                                               None
# 20-650636                                                               None
# 21-650644                                       dendermonde             None
# 22-650707                                                               None
# 23-650707                                                     Rommel Charles
# 25-651009                                                     Michel Pruvost
# 24-651009                                                               None
# 26-651069                                                               None
# 27-651089                                                               None
# 28-651111                                         moeskroen             None
# 29-651111                                                               None
# ...                                                     ...              ...
# 83827-3248245                                                           None
# 83823-3248245                                                           None
# 83824-3248245                                                           None
# 83825-3248245                                                           None
# 83828-3248346                                                           None
# 83829-3248346                                                           None
# 83830-3248346                                                           None
# 83831-3248370                                                           None
# 83833-3248416                                                Charles Tuytens
# 83834-3248416                                                           None
# 83835-3248416                                                           None
# 83836-3248416                                                           None
# 83832-3248416                                                 Arnaud Dreyfus
# 83839-3248444                                                           None
# 83838-3248444                                                           None
# 83837-3248444                                                           None
# 83840-3248446                                                    Guy Stephan
# 83842-3248467                                       louvain             None
# 83841-3248467                               louvain||leuven             None
# 83843-3248474                                                           None
# 83844-3248474                                                           None
# 83845-3248490                                                           None
# 83846-3248865                                                           None
# 83847-3248955                                                           None
# 83848-3248955                                                           None
# 83849-3248955                                                 Edouard Jacobs
# 83850-3248955                                                           None
# 83851-3248955                                                           None
# 83852-3248976                                                           None
# 83853-3248976                                                           None
#
#                                    extract_family
# unique_id
# 0-649635                           London Diamond
# 1-649635                   London Diamond Workers
# 2-649635       London Diamond Workers Trade Union
# 3-649756                                     None
# 4-649756                                   Cinema
# 5-649756                           Cinematographe
# 6-649756                                     None
# 7-649756                                     None
# 8-649858                                     None
# 9-649940                                  Delbecq
# 10-649981                                 Cambron
# 11-649981                                  Coinne
# 12-649981                                  Coisne
# 13-649981                                 Pruvost
# 14-650099                                    None
# 15-650298                                    None
# 16-650480                                     Oud
# 17-650574                          Bouchaute Oost
# 18-650574                          Bouchaute Oost
# 19-650636                                  Bridge
# 20-650636                                    None
# 21-650644                                    None
# 22-650707                                  Rommel
# 23-650707                                    None
# 25-651009                          Pruvost Michel
# 24-651009                                 Pruvost
# 26-651069                          Parent Schaken
# 27-651089                                   Macan
# 28-651111                           Brand Carette
# 29-651111                   Brand Carette Spinnen
# ...                                           ...
# 83827-3248245                             Rabarot
# 83823-3248245                                Cafe
# 83824-3248245                                Cafe
# 83825-3248245                            Henseval
# 83828-3248346                                None
# 83829-3248346                                None
# 83830-3248346                                None
# 83831-3248370                            Aernouts
# 83833-3248416                                None
# 83834-3248416                            Comptoir
# 83835-3248416                Thuysbaert De Ridder
# 83836-3248416                             Tuytens
# 83832-3248416                                None
# 83839-3248444                                 Col
# 83838-3248444                                Cafe
# 83837-3248444                                 Rue
# 83840-3248446                                None
# 83842-3248467                               Stade
# 83841-3248467                       Stade Tournoi
# 83843-3248474                  Rassenfosse Brouet
# 83844-3248474                      Serrurier Bovy
# 83845-3248490                                None
# 83846-3248865
# 83847-3248955                             Poorten
# 83848-3248955                             Poorten
# 83849-3248955                                None
# 83850-3248955                      Edouard Jacobs
# 83851-3248955                             Poorten
# 83852-3248976                             De Nave
# 83853-3248976                             Tuytens
#
# [83854 rows x 6 columns]

# %%
start_time = time.time()
extract_persons['isName'] = extract_persons['persons_names'].apply(lambda x: compare_names(x, noms_famille, liste_mots) if len(x)> 1 else None)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
start_time = time.time()
extract_persons['wikipedia_search'] = extract_persons['persons_names'].apply(lambda x: search_wikipedia(x) if len(x)> 1 else None)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
extract_persons

# %%
extract_persons.to_csv(r"extract_persons.csv", encoding='utf8')

# %%
annot.to_csv(r"annot.csv", encoding='utf8')
