# %%
from belgicapress import *
import time

#pd.set_option('display.max_rows', None) #pour visualiser toutes les lignes des dataframes, pas si gros dans ce cas-ci

# %%
annot = pd.read_csv(r'06_QueriesByVisit_towork2.csv', encoding="utf-8", engine="c", index_col="unique_id")

annot = annot.drop("query_tokens", axis=1)
annot = annot.rename(columns={'query_normalised': 'queries'})
annot.head()
# Out:
#            visitID  Column                             queries
# unique_id
# 0-649635    649635       0                      london diamond
# 1-649635    649635       1              london diamond-workers
# 2-649635    649635       2  london diamond-workers trade union
# 3-649756    649756       3                            bioscope
# 4-649756    649756       4                              cinéma

# %%
prenoms = pd.read_csv(r"C:\Users\Boulot\Desktop\BelgicaPress\prenoms.tsv", encoding="utf8")
prenoms = set([str(name).strip().lower() for name in prenoms.prenoms])

# %%
noms_famille = pd.read_csv(r"C:\Users\Boulot\Desktop\BelgicaPress\Names.csv", encoding="utf8", error_bad_lines=False)
noms_famille = set([name.strip().lower() for name in noms_famille.names])
# Out:
# b'Skipping line 3228: expected 1 fields, saw 2\nSkipping line 3569: expected 1 fields, saw 4\nSkipping line 5837: expected 1 fields, saw 2\nSkipping line 7827: expected 1 fields, saw 2\nSkipping line 8024: expected 1 fields, saw 2\nSkipping line 21500: expected 1 fields, saw 2\nSkipping line 24299: expected 1 fields, saw 2\nSkipping line 24522: expected 1 fields, saw 2\nSkipping line 33830: expected 1 fields, saw 2\nSkipping line 35900: expected 1 fields, saw 2\nSkipping line 37354: expected 1 fields, saw 2\nSkipping line 37606: expected 1 fields, saw 2\nSkipping line 39436: expected 1 fields, saw 2\nSkipping line 39458: expected 1 fields, saw 2\nSkipping line 40315: expected 1 fields, saw 2\nSkipping line 41123: expected 1 fields, saw 2\nSkipping line 43831: expected 1 fields, saw 2\nSkipping line 48327: expected 1 fields, saw 2\nSkipping line 50428: expected 1 fields, saw 2\nSkipping line 51721: expected 1 fields, saw 2\nSkipping line 54022: expected 1 fields, saw 2\nSkipping line 54241: expected 1 fields, saw 2\nSkipping line 59653: expected 1 fields, saw 2\nSkipping line 59715: expected 1 fields, saw 2\nSkipping line 61716: expected 1 fields, saw 2\nSkipping line 65140: expected 1 fields, saw 2\nSkipping line 68379: expected 1 fields, saw 2\nSkipping line 70278: expected 1 fields, saw 2\nSkipping line 70954: expected 1 fields, saw 2\nSkipping line 74319: expected 1 fields, saw 2\nSkipping line 74402: expected 1 fields, saw 2\nSkipping line 75902: expected 1 fields, saw 2\nSkipping line 79779: expected 1 fields, saw 2\nSkipping line 82995: expected 1 fields, saw 2\nSkipping line 85910: expected 1 fields, saw 2\nSkipping line 85918: expected 1 fields, saw 2\nSkipping line 87530: expected 1 fields, saw 2\nSkipping line 89562: expected 1 fields, saw 2\nSkipping line 95480: expected 1 fields, saw 2\nSkipping line 96507: expected 1 fields, saw 2\nSkipping line 96892: expected 1 fields, saw 2\nSkipping line 96893: expected 1 fields, saw 2\nSkipping line 97589: expected 1 fields, saw 2\nSkipping line 97634: expected 1 fields, saw 2\nSkipping line 99986: expected 1 fields, saw 2\nSkipping line 102010: expected 1 fields, saw 2\nSkipping line 102343: expected 1 fields,
pd.read_csv(r"C:\Users\Boulot\Desktop\BelgicaPress\communes_et_sections_noms_unifies.csv", encoding="utf8")
geo = geo.drop_duplicates(['noms_unifie'])
geo['lower'] = geo['noms_unifie'].str.lower()
lieux_be = set([str(name).strip() for name in geo.lower])

# %%
annot["extract_lieux_be"] = annot['queries'].apply(lambda x: get_lieux_clean(x, lieux_be, prenoms))
annot.head()
# Out:
#            visitID  Column                             queries  \
# unique_id
# 0-649635    649635       0                      london diamond
# 1-649635    649635       1              london diamond-workers
# 2-649635    649635       2  london diamond-workers trade union
# 3-649756    649756       3                            bioscope
# 4-649756    649756       4                              cinéma
#
#           extract_lieux_be
# unique_id
# 0-649635
# 1-649635
# 2-649635
# 3-649756
# 4-649756

# %%
annot = tidy_split(annot, 'extract_lieux_be', sep='||')
annot
# Out:
#                visitID  Column  \
# unique_id
# 0-649635        649635       0
# 1-649635        649635       1
# 2-649635        649635       2
# 3-649756        649756       3
# 4-649756        649756       4
# 5-649756        649756       5
# 6-649756        649756       6
# 7-649756        649756       7
# 8-649858        649858       8
# 9-649940        649940       9
# 10-649981       649981      10
# 11-649981       649981      11
# 12-649981       649981      12
# 13-649981       649981      13
# 14-650099       650099      14
# 15-650298       650298      15
# 16-650480       650480      16
# 17-650574       650574      17
# 17-650574       650574      17
# 17-650574       650574      17
# 17-650574       650574      17
# 18-650574       650574      18
# 18-650574       650574      18
# 18-650574       650574      18
# 18-650574       650574      18
# 19-650636       650636      19
# 20-650636       650636      20
# 21-650644       650644      21
# 22-650707       650707      22
# 23-650707       650707      23
# ...                ...     ...
# 83823-3248245  3248245   83823
# 83824-3248245  3248245   83824
# 83825-3248245  3248245   83825
# 83828-3248346  3248346   83828
# 83829-3248346  3248346   83829
# 83830-3248346  3248346   83830
# 83831-3248370  3248370   83831
# 83833-3248416  3248416   83833
# 83834-3248416  3248416   83834
# 83835-3248416  3248416   83835
# 83836-3248416  3248416   83836
# 83832-3248416  3248416   83832
# 83839-3248444  3248444   83839
# 83838-3248444  3248444   83838
# 83837-3248444  3248444   83837
# 83840-3248446  3248446   83840
# 83842-3248467  3248467   83842
# 83841-3248467  3248467   83841
# 83841-3248467  3248467   83841
# 83843-3248474  3248474   83843
# 83844-3248474  3248474   83844
# 83845-3248490  3248490   83845
# 83846-3248865  3248865   83846
# 83847-3248955  3248955   83847
# 83848-3248955  3248955   83848
# 83849-3248955  3248955   83849
# 83850-3248955  3248955   83850
# 83851-3248955  3248955   83851
# 83852-3248976  3248976   83852
# 83853-3248976  3248976   83853
#
#                                                          queries  \
# unique_id
# 0-649635                                          london diamond
# 1-649635                                  london diamond-workers
# 2-649635                      london diamond-workers trade union
# 3-649756                                                bioscope
# 4-649756                                                  cinéma
# 5-649756                                          cinématographe
# 6-649756                                         cinématographie
# 7-649756                                       cinématographique
# 8-649858                                      soucoupes volantes
# 9-649940                                        delbecq guignies
# 10-649981                                                cambron
# 11-649981                                                 coinne
# 12-649981                                                 coisne
# 13-649981                                                pruvost
# 14-650099                                            dendermonde
# 15-650298                                            dendermonde
# 16-650480                                           oud-strijder
# 17-650574      assenede bassevelde boekhoute bouchaute oost-e...
# 17-650574      assenede bassevelde boekhoute bouchaute oost-e...
# 17-650574      assenede bassevelde boekhoute bouchaute oost-e...
# 17-650574      assenede bassevelde boekhoute bouchaute oost-e...
# 18-650574      assenede bassevelde bouchaute boekhoute oost-e...
# 18-650574      assenede bassevelde bouchaute boekhoute oost-e...
# 18-650574      assenede bassevelde bouchaute boekhoute oost-e...
# 18-650574      assenede bassevelde bouchaute boekhoute oost-e...
# 19-650636                                                 bridge
# 20-650636                                                 britch
# 21-650644                                            dendermonde
# 22-650707                                                 rommel
# 23-650707                                         rommel charles
# ...                                                          ...
# 83823-3248245                                    café restaurant
# 83824-3248245                                    café-restaurant
# 83825-3248245                                           henseval
# 83828-3248346                                drame de braconnage
# 83829-3248346                                     stroopersdrama
# 83830-3248346                                 wildstroopersdrama
# 83831-3248370                                           aernouts
# 83833-3248416                                    charles tuytens
# 83834-3248416                  comptoir commercial et industriel
# 83835-3248416                               thuysbaert-de ridder
# 83836-3248416                                            tuytens
# 83832-3248416                                     arnaud dreyfus
# 83839-3248444                                             h. col
# 83838-3248444                                    café-restaurant
# 83837-3248444                               6, rue de la station
# 83840-3248446                                        guy stephan
# 83842-3248467                 stade, louvain, louvaniste,leuven,
# 83841-3248467  stade, louvain, louvaniste, football, sports, ...
# 83841-3248467  stade, louvain, louvaniste, football, sports, ...
# 83843-3248474                                 rassenfosse-brouet
# 83844-3248474                                     serrurier-bovy
# 83845-3248490                                             horrue
# 83846-3248865                                 neder over hembeek
# 83847-3248955                                      arved poorten
# 83848-3248955                                      arwed poorten
# 83849-3248955                                     edouard jacobs
# 83850-3248955                      edouard jacobs violoncelliste
# 83851-3248955                             poorten violoncelliste
# 83852-3248976                                            de nave
# 83853-3248976                                            tuytens
#
#               extract_lieux_be
# unique_id
# 0-649635
# 1-649635
# 2-649635
# 3-649756
# 4-649756
# 5-649756
# 6-649756
# 7-649756
# 8-649858
# 9-649940              guignies
# 10-649981
# 11-649981
# 12-649981
# 13-649981
# 14-650099          dendermonde
# 15-650298          dendermonde
# 16-650480
# 17-650574           bassevelde
# 17-650574            boekhoute
# 17-650574          oost-eecloo
# 17-650574             assenede
# 18-650574           bassevelde
# 18-650574            boekhoute
# 18-650574          oost-eecloo
# 18-650574             assenede
# 19-650636
# 20-650636
# 21-650644          dendermonde
# 22-650707
# 23-650707
# ...                        ...
# 83823-3248245
# 83824-3248245
# 83825-3248245
# 83828-3248346
# 83829-3248346
# 83830-3248346
# 83831-3248370
# 83833-3248416
# 83834-3248416
# 83835-3248416
# 83836-3248416
# 83832-3248416
# 83839-3248444
# 83838-3248444
# 83837-3248444
# 83840-3248446
# 83842-3248467          louvain
# 83841-3248467          louvain
# 83841-3248467           leuven
# 83843-3248474
# 83844-3248474
# 83845-3248490
# 83846-3248865
# 83847-3248955
# 83848-3248955
# 83849-3248955
# 83850-3248955
# 83851-3248955
# 83852-3248976
# 83853-3248976
#
# [84915 rows x 4 columns]

# %% [markdown]
# extract_geonames = pd.DataFrame(annot['extract_lieux_be'].dropna().unique(), columns = ["name"])
#
# geonames = extract_geonames.merge(geo, left_on='name', right_on='lower', how='left')

# %%
annot_geo = pd.merge(annot, geo, left_on="extract_lieux_be", right_on="lower", how="left")
annot_geo
# Out:
#        visitID  Column                                            queries  \
# 0       649635       0                                     london diamond
# 1       649635       1                             london diamond-workers
# 2       649635       2                 london diamond-workers trade union
# 3       649756       3                                           bioscope
# 4       649756       4                                             cinéma
# 5       649756       5                                     cinématographe
# 6       649756       6                                    cinématographie
# 7       649756       7                                  cinématographique
# 8       649858       8                                 soucoupes volantes
# 9       649940       9                                   delbecq guignies
# 10      649981      10                                            cambron
# 11      649981      11                                             coinne
# 12      649981      12                                             coisne
# 13      649981      13                                            pruvost
# 14      650099      14                                        dendermonde
# 15      650099      14                                        dendermonde
# 16      650099      14                                        dendermonde
# 17      650298      15                                        dendermonde
# 18      650298      15                                        dendermonde
# 19      650298      15                                        dendermonde
# 20      650480      16                                       oud-strijder
# 21      650574      17  assenede bassevelde boekhoute bouchaute oost-e...
# 22      650574      17  assenede bassevelde boekhoute bouchaute oost-e...
# 23      650574      17  assenede bassevelde boekhoute bouchaute oost-e...
# 24      650574      17  assenede bassevelde boekhoute bouchaute oost-e...
# 25      650574      17  assenede bassevelde boekhoute bouchaute oost-e...
# 26      650574      18  assenede bassevelde bouchaute boekhoute oost-e...
# 27      650574      18  assenede bassevelde bouchaute boekhoute oost-e...
# 28      650574      18  assenede bassevelde bouchaute boekhoute oost-e...
# 29      650574      18  assenede bassevelde bouchaute boekhoute oost-e...
# ...        ...     ...                                                ...
# 90751  3248245   83824                                    café-restaurant
# 90752  3248245   83825                                           henseval
# 90753  3248346   83828                                drame de braconnage
# 90754  3248346   83829                                     stroopersdrama
# 90755  3248346   83830                                 wildstroopersdrama
# 90756  3248370   83831                                           aernouts
# 90757  3248416   83833                                    charles tuytens
# 90758  3248416   83834                  comptoir commercial et industriel
# 90759  3248416   83835                               thuysbaert-de ridder
# 90760  3248416   83836                                            tuytens
# 90761  3248416   83832                                     arnaud dreyfus
# 90762  3248444   83839                                             h. col
# 90763  3248444   83838                                    café-restaurant
# 90764  3248444   83837                               6, rue de la station
# 90765  3248446   83840                                        guy stephan
# 90766  3248467   83842                 stade, louvain, louvaniste,leuven,
# 90767  3248467   83841  stade, louvain, louvaniste, football, sports, ...
# 90768  3248467   83841  stade, louvain, louvaniste, football, sports, ...
# 90769  3248467   83841  stade, louvain, louvaniste, football, sports, ...
# 90770  3248474   83843                                 rassenfosse-brouet
# 90771  3248474   83844                                     serrurier-bovy
# 90772  3248490   83845                                             horrue
# 90773  3248865   83846                                 neder over hembeek
# 90774  3248955   83847                                      arved poorten
# 90775  3248955   83848                                      arwed poorten
# 90776  3248955   83849                                     edouard jacobs
# 90777  3248955   83850                      edouard jacobs violoncelliste
# 90778  3248955   83851                             poorten violoncelliste
# 90779  3248976   83852                                            de nave
# 90780  3248976   83853                                            tuytens
#
#       extract_lieux_be nom_original  noms_unifie        lower
# 0                               NaN          NaN          NaN
# 1                               NaN          NaN          NaN
# 2                               NaN          NaN          NaN
# 3                               NaN          NaN          NaN
# 4                               NaN          NaN          NaN
# 5                               NaN          NaN          NaN
# 6                               NaN          NaN          NaN
# 7                               NaN          NaN          NaN
# 8                               NaN          NaN          NaN
# 9             guignies     Guignies     Guignies     guignies
# 10                              NaN          NaN          NaN
# 11                              NaN          NaN          NaN
# 12                              NaN          NaN          NaN
# 13                              NaN          NaN          NaN
# 14         dendermonde  DENDERMONDE  Dendermonde  dendermonde
# 15         dendermonde  DENDERMONDE  dendermonde  dendermonde
# 16         dendermonde  DENDERMONDE  DENDERMONDE  dendermonde
# 17         dendermonde  DENDERMONDE  Dendermonde  dendermonde
# 18         dendermonde  DENDERMONDE  dendermonde  dendermonde
# 19         dendermonde  DENDERMONDE  DENDERMONDE  dendermonde
# 20                              NaN          NaN          NaN
# 21          bassevelde   Bassevelde   Bassevelde   bassevelde
# 22           boekhoute     Boekhout    Boekhoute    boekhoute
# 23         oost-eecloo    Oosteeklo  Oost-Eecloo  oost-eecloo
# 24            assenede     ASSENEDE     Assenede     assenede
# 25            assenede     ASSENEDE     ASSENEDE     assenede
# 26          bassevelde   Bassevelde   Bassevelde   bassevelde
# 27           boekhoute     Boekhout    Boekhoute    boekhoute
# 28         oost-eecloo    Oosteeklo  Oost-Eecloo  oost-eecloo
# 29            assenede     ASSENEDE     Assenede     assenede
# ...                ...          ...          ...          ...
# 90751                           NaN          NaN          NaN
# 90752                           NaN          NaN          NaN
# 90753                           NaN          NaN          NaN
# 90754                           NaN          NaN          NaN
# 90755                           NaN          NaN          NaN
# 90756                           NaN          NaN          NaN
# 90757                           NaN          NaN          NaN
# 90758                           NaN          NaN          NaN
# 90759                           NaN          NaN          NaN
# 90760                           NaN          NaN          NaN
# 90761                           NaN          NaN          NaN
# 90762                           NaN          NaN          NaN
# 90763                           NaN          NaN          NaN
# 90764                           NaN          NaN          NaN
# 90765                           NaN          NaN          NaN
# 90766          louvain       LEUVEN      Louvain      louvain
# 90767          louvain       LEUVEN      Louvain      louvain
# 90768           leuven       LEUVEN       LEUVEN       leuven
# 90769           leuven       LEUVEN       Leuven       leuven
# 90770                           NaN          NaN          NaN
# 90771                           NaN          NaN          NaN
# 90772                           NaN          NaN          NaN
# 90773                           NaN          NaN          NaN
# 90774                           NaN          NaN          NaN
# 90775                           NaN          NaN          NaN
# 90776                           NaN          NaN          NaN
# 90777                           NaN          NaN          NaN
# 90778                           NaN          NaN          NaN
# 90779                           NaN          NaN          NaN
# 90780                           NaN          NaN          NaN
#
# [90781 rows x 7 columns]

# %%
#PROBLEME !
#df_merged = pd.merge(annot_geo, communes_complet.drop_duplicates(['noms_unifie']), left_on="nom_original", right_on="nom_original", how="left")
#df_merged

# %%
patronymes_locaux = []
annot['extract_persons'] = annot['queries'].apply(lambda x: get_personnes_clean(x, prenoms, lieux_be))
seen = set()
seen_add = seen.add
patronymes_locaux = [x.lower() for x in patronymes_locaux if not (x in seen or seen_add(x)) and x is not '']

# %%
patronymes_locaux.sort()
patronymes_locaux
# Out:
# []

# %%
annot['extract_family'] = annot['queries'].apply(lambda x: get_family_name(x, prenoms, noms_famille, lieux_be))

# %%
extract_persons = pd.DataFrame(annot['extract_persons'].dropna().unique(), columns = ["persons_names"])
extract_persons
# Out:
#                         persons_names
# 0                      Diamond London
# 1
# 2                      Rommel Charles
# 3                      Michel Pruvost
# 4                   Bernard Israelite
# 5                        Bridge Whist
# 6                     Daniel De Lange
# 7                   Wilhelmine Clauss
# 8                    Amalia Rodrigues
# 9                        Gillet Amour
# 10                   Gillet Lamouline
# 11                 Felix Van De Weghe
# 12                       Anna Nellens
# 13                      Marcel Dupuis
# 14                   Victor Guillemin
# 15    Victor Guillemin Albert Gombert
# 16                  Beernaert Wilmart
# 17                       Gulden Valse
# 18                     Pierre Willems
# 19          Pierre Willems Professeur
# 20                     Pieter Willems
# 21                    Denis Jacquemin
# 22                      Albert Panier
# 23                         Jean Bahut
# 24                       Andre Boelen
# 25                       Gaston Block
# 26                     Mendes Catulle
# 27                      Vincent Lebbe
# 28                     Stevens Smeers
# 29                   Stevens Stacquet
# ...                               ...
# 9021                   Bernhard Meyer
# 9022                  Meyer Africains
# 9023                 Rochel Africains
# 9024                 Rochel Spectacle
# 9025                     Meyer Wahehe
# 9026                       Marc Sleen
# 9027                  Rodolphe Tppfer
# 9028                Willy Vandersteen
# 9029                   Frans Lenaerts
# 9030                   Charles Miller
# 9031                         Paul Bor
# 9032                      Paul Dangla
# 9033                   Denijs Balcaen
# 9034                Denijs Vandevenne
# 9035                       Ali Autome
# 9036                    Batiste Royal
# 9037                    Eugenio Bruni
# 9038                   Arnaud Dreyfus
# 9039                   Eleonore Gomez
# 9040                   Francois Gomez
# 9041                    Jacques Gomez
# 9042                 Leontine Lefevre
# 9043                   Marie Leclercq
# 9044          Marie Therese Desomberg
# 9045                     Henry Krauss
# 9046                    Martin Robyns
# 9047                  Charles Tuytens
# 9048                      Guy Stephan
# 9049                   Edouard Jacobs
# 9050    Edouard Jacobs Violoncelliste
#
# [9051 rows x 1 columns]

# %% [markdown]
# start_time = time.time()
# extract_persons['wikipedia_person'] = extract_persons['persons_names'].apply(lambda x: get_wikipedia(x) if len(x)> 1 else None)
# print("--- %s seconds ---" % (time.time() - start_time))

# %% [markdown]
# start_time = time.time()
# extract_persons['wikipedia_person'] = extract_persons['persons_names'].apply(lambda x: get_wikipedia(x) if len(x)> 1 else None)
# print("--- %s seconds ---" % (time.time() - start_time))

# %%
annot_geo

# %%
annot

# %%
start_time = time.time()
extract_persons['isName'] = extract_persons['persons_names'].apply(lambda x: compare_names(x, noms_famille, liste_mots) if len(x)> 1 else None)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.023016691207885742 seconds ---

# %%
start_time = time.time()
extract_persons['wikipedia_search'] = extract_persons['persons_names'].apply(lambda x: search_wikipedia(x) if len(x)> 1 else None)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
extract_persons
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1a8479f1cdfc> in <module>()
# ----> 1 extract_persons
#
# NameError: name 'extract_persons' is not defined

# %%
extract_persons.to_csv(r"extract_persons.csv", encoding='utf8')

# %%
annot.to_csv(r"annot.csv", encoding='utf8')
